# %% [markdown]
# # CUSTOMER CHURN ANALYSIS
#
#
# Live chat support is a way for customers to have real-time, back-and-forth conversations with support agents. Using live chat software embedded on a company’s website, customers can send their questions to a person who can quickly reply to them in the same small window.
#
# Live chat software can be integrated right into your customer’s workflow through a consistently available button or link on your website or in your app. Your customer doesn’t need to hunt down a special contact page or dig up an email address; they know exactly where to go when they need help.
#
# Chat etiquette plays a huge role in customer service. Professional and authentic interaction with clients goes far beyond the opportunity to make a sale. It helps to build a lasting relationship with the customer, inspire future communication and create fans and advocates of your brand.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ![download1.jfif](attachment:download1.jfif)

# %% [markdown]
# # EDA (Exploratory Data Analysis)
#
#
# A . The reasoning behind this approach was to examine the data before building a model.
#
# B . Today almost every Data scientists and analysts spend most of their time in Data Wrangling and Exploratory Data Analysis also known as EDA.

# %% [markdown]
# # What is Exploratory Data Analysis?
#
#
# Exploratory Data Analysis or EDA technique is used for getting insights from the data. Data Scientists and Analysts try to find different patterns, relations, and anomalies in the data using some statistical graphs and other visualization techniques. Following things are part of EDA :
#
#
# A . Get maximum insights from a data set.
#
# B . Uncover underlying structure.
#
# C . Extract important variables from the dataset.
#
# D . Detect outliers and anomalies(if any).
#
# E . Test underlying assumptions.
#
# F . Determine the optimal factor settings.

# %% [markdown]
# # Why EDA is important?
#
# The main purpose of EDA is to :
#
# A . Detect any errors or Outliers as well.
#
# B . To understand different patterns in the data.
#
# C . It allows Analysts to understand the data better before making any assumptions.
#
# D . The outcomes of EDA helps businesses to know their customers, expand their business and take decisions accordingly.

# %% [markdown]
# # How to perform EDA?

# %% [markdown]
# Following steps are most commonly used to perform EDA:

# %% [markdown]
# # Import libraries and load dataset

# %%
import numpy as np    #for numneric calculations  
import pandas as pd   #for dataframe operations 
import matplotlib.pyplot as plt    #for plotting 
import seaborn as sns     #for avance plotting 
import scipy.stats as sts #for statistical calculations 
import warnings      #for removing warnings 
import statsmodels.api as sm  #for advance statistical calculations

# %%
df = pd.read_csv("Copy of Telco_customer_churn 1.csv")
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %% [markdown]
# # Description of columns are as follows:

# %% [markdown]
# CustomerID: A unique ID that identifies each customer.
#
#
# Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
#
# Country: The country of the customer’s primary residence.
#
#
# State: The state of the customer’s primary residence.
#
#
# City: The city of the customer’s primary residence.
#
#
# Zip Code: The zip code of the customer’s primary residence.
#
#
# Lat Long: The combined latitude and longitude of the customer’s primary residence.
#
#
# Latitude: The latitude of the customer’s primary residence.
#
#
# Longitude: The longitude of the customer’s primary residence.
#
#
# Gender: The customer’s gender: Male, Female
#
#
# Senior Citizen: Indicates if the customer is 65 or older: Yes, No
#
#
# Partner: Indicate if the customer has a partner: Yes, No
#
#
# Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
#
# Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
#
# Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
#
#
# Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
#
# Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
#
# Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
#
# Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
#
# Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
#
# Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
#
# Streaming TV: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
#
# Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
#
# Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
#
# Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
#
#
# Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
#
# Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
#
#
# Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
#
# Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
#
#
# Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
#
# Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
#
# CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
#
# Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category.

# %%
# Lets check the shape and columns of the dataset.

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 33)

# %%
## Lets check the data types of every columns

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'],errors='coerce')

# %%
df["Total Charges"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Let's check if datasety contains any Null , Nan values or not ?

# %%
df.isnull().sum()/100
# Out:
# CustomerID            0.00
# Count                 0.00
# Country               0.00
# State                 0.00
# City                  0.00
# Zip Code              0.00
# Lat Long              0.00
# Latitude              0.00
# Longitude             0.00
# Gender                0.00
# Senior Citizen        0.00
# Partner               0.00
# Dependents            0.00
# Tenure Months         0.00
# Phone Service         0.00
# Multiple Lines        0.00
# Internet Service      0.00
# Online Security       0.00
# Online Backup         0.00
# Device Protection     0.00
# Tech Support          0.00
# Streaming TV          0.00
# Streaming Movies      0.00
# Contract              0.00
# Paperless Billing     0.00
# Payment Method        0.00
# Monthly Charges       0.00
# Total Charges         0.11
# Churn Label           0.00
# Churn Value           0.00
# Churn Score           0.00
# CLTV                  0.00
# Churn Reason         51.74
# dtype: float64

# %% [markdown]
# As we can see from the above that except Churn Reason column, which contains 51% null or empty values in the datatset as compared to other columns. Since, very less customers have given the reason for leaving the facility and only 1800 customers gave the feedback. Well, in this case study, we will try to find that how we can retain the customers.

# %%
df["Churn Reason"].value_counts()
# Out:
# Attitude of support person                   192
# Competitor offered higher download speeds    189
# Competitor offered more data                 162
# Don't know                                   154
# Competitor made better offer                 140
# Attitude of service provider                 135
# Competitor had better devices                130
# Network reliability                          103
# Product dissatisfaction                      102
# Price too high                                98
# Service dissatisfaction                       89
# Lack of self-service on Website               88
# Extra data charges                            57
# Moved                                         53
# Lack of affordable download/upload speed      44
# Limited range of services                     44
# Long distance charges                         44
# Poor expertise of phone support               20
# Poor expertise of online support              19
# ...

# %% [markdown]
# Here, we can see 192 customers left because of bad attitude of support person and 189 because of Competitor offered higher download speeds

# %%
# lets see the unique values

# %%
df.nunique()
# Out:
# CustomerID           7043
# Count                   1
# Country                 1
# State                   1
# City                 1129
# Zip Code             1652
# Lat Long             1652
# Latitude             1652
# Longitude            1651
# Gender                  2
# Senior Citizen          2
# Partner                 2
# Dependents              2
# Tenure Months          73
# Phone Service           2
# Multiple Lines          3
# Internet Service        3
# Online Security         3
# Online Backup           3
# Device Protection       3
# Tech Support            3
# Streaming TV            3
# Streaming Movies        3
# Contract                3
# Paperless Billing       2
# Payment Method          4
# Monthly Charges      1585
# Total Charges        6530
# Churn Label             2
# Churn Value             2
# Churn Score            85
# CLTV                 3438
# Churn Reason           20
# dtype: int64

# %%
# As there are few columns which is not use for further analysis, we can drop it.

# %%
data = df.copy()

# %%
df.drop(["Count" , "Zip Code" , "Lat Long", "Churn Value"] , axis = 1 ,  inplace = True)

# %%
df.head()
# Out:
#    CustomerID        Country       State         City   Latitude   Longitude  \
# 0  3668-QPYBK  United States  California  Los Angeles  33.964131 -118.272783
# 1  9237-HQITU  United States  California  Los Angeles  34.059281 -118.307420
# 2  9305-CDSKC  United States  California  Los Angeles  34.048013 -118.293953
# 3  7892-POOKP  United States  California  Los Angeles  34.062125 -118.315709
# 4  0280-XJGEX  United States  California  Los Angeles  34.039224 -118.266293
#
#    Gender Senior Citizen Partner Dependents  ...  Streaming Movies  \
# 0    Male             No      No         No  ...                No
# 1  Female             No      No        Yes  ...                No
# 2  Female             No      No        Yes  ...               Yes
# 3  Female             No     Yes        Yes  ...               Yes
# 4    Male             No      No        Yes  ...               Yes
#
#          Contract Paperless Billing             Payment Method  \
# ...

# %%
# Time to see the Statistical matrix

# %%
df.describe(include = "all")
# Out:
#         CustomerID        Country       State         City     Latitude  \
# count         7043           7043        7043         7043  7043.000000
# unique        7043              1           1         1129          NaN
# top     1550-LOAHA  United States  California  Los Angeles          NaN
# freq             1           7043        7043          305          NaN
# mean           NaN            NaN         NaN          NaN    36.282441
# std            NaN            NaN         NaN          NaN     2.455723
# min            NaN            NaN         NaN          NaN    32.555828
# 25%            NaN            NaN         NaN          NaN    34.030915
# 50%            NaN            NaN         NaN          NaN    36.391777
# 75%            NaN            NaN         NaN          NaN    38.224869
# max            NaN            NaN         NaN          NaN    41.962127
#
#           Longitude Gender Senior Citizen Partner Dependents  ...  \
# ...

# %% [markdown]
# # Observations
#
# 1 . "8071-SBTRN" is the CustomerID which is at the top position based on multiple factors.
#
# 2 . It is evident that many customers are from Los Angeles, United States.
#
# 3 . Many people perfer to take month-to-month subscription and perfer to pay by Electronic check method.
#
# 4 . The Average Monthly Charges of particular contract is $65 and maximum it goes upto $119.
#
# 5 . Males are the most frequent to take contract as campared to females.
#
# 6 . Due the the bad attitude of a support person, many customers are churning the facilities.

# %% [markdown]
# # Its time to visualize the data attributes.

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
df.head()
# Out:
#    CustomerID        Country       State         City   Latitude   Longitude  \
# 0  3668-QPYBK  United States  California  Los Angeles  33.964131 -118.272783
# 1  9237-HQITU  United States  California  Los Angeles  34.059281 -118.307420
# 2  9305-CDSKC  United States  California  Los Angeles  34.048013 -118.293953
# 3  7892-POOKP  United States  California  Los Angeles  34.062125 -118.315709
# 4  0280-XJGEX  United States  California  Los Angeles  34.039224 -118.266293
#
#    Gender Senior Citizen Partner Dependents  ...  Streaming Movies  \
# 0    Male             No      No         No  ...                No
# 1  Female             No      No        Yes  ...                No
# 2  Female             No      No        Yes  ...               Yes
# 3  Female             No     Yes        Yes  ...               Yes
# 4    Male             No      No        Yes  ...               Yes
#
#          Contract Paperless Billing             Payment Method  \
# ...

# %%
fig, axis = plt.subplots(nrows = 3 , ncols = 2 , figsize = (10 , 10))
sns.countplot(data = df , x = df["Gender"] , ax = axis[0 , 0])
sns.countplot(data = df , x = df["Senior Citizen"] , ax = axis[0 , 1])
sns.countplot(data = df , x = df["Partner"] , ax = axis[1,0])
sns.countplot(data = df , x = df["Dependents"] , ax = axis[1,1])
sns.histplot(data = df , x = df["Tenure Months"] , ax = axis[2,0])
sns.countplot(data = df , x = df["Phone Service"] , ax = axis[2,1])
plt.tight_layout
plt.show()

# %%
fig, axis = plt.subplots(nrows = 3 , ncols = 2 , figsize = (10 , 10))
sns.countplot(data = df , x = df["Multiple Lines"] , ax = axis[0 , 0])
sns.countplot(data = df , x = df["Internet Service"] , ax = axis[0 , 1])
sns.countplot(data = df , x = df["Online Security"] , ax = axis[1,0])
sns.countplot(data = df , x = df["Online Backup"] , ax = axis[1,1])
sns.countplot(data = df , x = df["Device Protection"] , ax = axis[2,0])
sns.countplot(data = df , x = df["Tech Support"] , ax = axis[2,1])
plt.tight_layout
plt.show()

# %%
fig, axis = plt.subplots(nrows = 3 , ncols = 2 , figsize = (10 , 10))
sns.countplot(data = df , x = df["Streaming TV"] , ax = axis[0 , 0])
sns.countplot(data = df , x = df["Streaming Movies"] , ax = axis[0 , 1])
sns.countplot(data = df , x = df["Contract"] , ax = axis[1,0])
sns.countplot(data = df , x = df["Paperless Billing"] , ax = axis[1,1])
sns.countplot(data = df , x = df["Payment Method"] , ax = axis[2,0])
sns.countplot(data = df , x = df["Churn Label"] , ax = axis[2,1])
plt.tight_layout
plt.show()

# %%
fig, axis = plt.subplots(nrows = 1, ncols = 4 , figsize = (10, 5))
sns.boxplot(df["Monthly Charges"] , data = df , ax = axis[0] , color="r")
sns.boxplot(df["Churn Score"], data = df , ax = axis[1] ,  color = "y")
sns.boxplot(df["CLTV"] ,data = df , ax = axis[2] ,  color = "g")
sns.boxplot(df["Total Charges"] ,data = df , ax = axis[3])
plt.tight_layout()
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# # Observations
#
# 1 . Males are slighly more in number as compared to females in order to take the facilities.
#
# 2 . It has been observed that mostly customers are not belong to senior citizen category and they are mostly single. However, they are mostly self dependent it means they are not rely on their childern and family.
#
# 3 . Customers mostly perfer to stay with the company between 0 to a month. Moreover, the maximum tanuarity is 70 months.
#
# 4 . It indicates that many customers subscribed for phone services as well as multiple lines to the company.
#
# 5 . It is observed that customers likes to use Fibre optics as a internet services , less number of people subscribes to the online security and online backup services that has been provided by the company.
#
# 6 . Myraid Customers do not opt for device protection and technical support.
#
# 7 . Approximately 4000 customers are perfer to take Month-to-month contract. There are less number of people who buy one year subscription.
#
# 8 . There are very high chances that customers pay to the company by electronic cheques.
#
# 9 . Customers have not left the company in this quater.
#
# 10 . The maximum monthly charges are lying between 80 to $100 .

# %% [markdown]
# # Bivariate Analysis

# %%
fig, axis = plt.subplots(nrows=2,ncols=2,figsize=(10,10))
sns.barplot(x=df["Gender"],y=df["Monthly Charges"],data=df,hue=df["Churn Label"], ax=axis[0,0])
sns.barplot(x=df["Senior Citizen"],y=df["Monthly Charges"],data=df,hue=df["Churn Label"], ax=axis[0,1])
sns.barplot(x=df["Partner"],y=df["Monthly Charges"],data=df,hue=df["Churn Label"], ax=axis[1,0])
sns.barplot(x=df["Dependents"],y=df["Monthly Charges"],data=df,hue=df["Churn Label"], ax=axis[1,1])
plt.tight_layout
plt.show()

# %% [markdown]
# # Insights-
#
# 1 . From the plot we can observe that the monthly expenditure is almost same for men and women but when seen in terms of churn, the men and women who churned from the service paid more monthly charges than the retained ones that is they opted for more no of services and somehow got dissapointed or got better offers.
#
# 2 . Senior citizens have a higher monthly expenditure of the services for both irrespective of churning.
#
# 3 . Customers which have partners and that do not does not have have much affect on churning as both follow same pattern.
#
# 4 . Customers which do not have dependents and have churned have high monthly charges.

# %%
fig, axis = plt.subplots(nrows=2,ncols=2,figsize=(10,10))
sns.lineplot(x=df["Tenure Months"],y=df["Monthly Charges"],data=df,hue=df["Churn Label"],ax=axis[0,0])
sns.lineplot(x=df["Tenure Months"],y=df["Total Charges"],data=df,hue=df["Churn Label"],palette=['r', 'g'], linewidth=2.5,ax=axis[0,1])
sns.barplot(x=df["Phone Service"],y=df["Monthly Charges"],data=df,hue=df["Churn Label"],ax=axis[1,0])
sns.barplot(x=df["Internet Service"],y=df["Monthly Charges"],data=df,hue=df["Churn Label"],ax=axis[1,1])
plt.tight_layout
plt.show()

# %% [markdown]
# # Insights-
#
# 1 . As the tenure of months increase the monthly charges are also increasing for both churned and non churned customers.
#
# 2 . As the tenure of months increase the total charges are increasing much faster of churned customers as compared to non-churned customers.
#
# 3 . Customers that have opted for phone services and have churned had high montly charges.
#
# 4 . Fiber optics have a higher monthly charges as compare to others and does not affect whether churned or not almost same charges.

# %%
#Creating a new sub df containing only churned customer data

df_churn = df[df["Churn Label"]=="Yes"]
df_churn
# Out:
#       CustomerID        Country       State          City   Latitude  \
# 0     3668-QPYBK  United States  California   Los Angeles  33.964131
# 1     9237-HQITU  United States  California   Los Angeles  34.059281
# 2     9305-CDSKC  United States  California   Los Angeles  34.048013
# 3     7892-POOKP  United States  California   Los Angeles  34.062125
# 4     0280-XJGEX  United States  California   Los Angeles  34.039224
# ...          ...            ...         ...           ...        ...
# 1864  1699-HPSBG  United States  California  Palm Springs  33.745746
# 1865  8775-CEBBJ  United States  California        Seeley  32.790282
# 1866  6894-LFHLY  United States  California         Vidal  34.264124
# 1867  0639-TSIQW  United States  California   White Water  33.972293
# 1868  8361-LTMKD  United States  California  Apple Valley  34.550820
#
#        Longitude  Gender Senior Citizen Partner Dependents  ...  \
# 0    -118.272783    Male             No      No         No  ...
# ...

# %%
Contract = df_churn["Contract"].value_counts().to_list()
labels = df_churn["Contract"].unique()
plt.pie(Contract,labels=labels,startangle=90,wedgeprops={'linewidth':1.5,'edgecolor':'black'},shadow=True)
plt.title("Types of Contract")
plt.show()

# %% [markdown]
# Majority of the churned customers had month-to-month contract.

# %%
Payment_method = df_churn["Payment Method"].value_counts().to_list()
labels_ = df_churn["Payment Method"].unique()
plt.pie(Payment_method,labels=labels_,startangle=90,wedgeprops={'linewidth':1.5,'edgecolor':'black'},shadow=True)
plt.title("Types of Payment Method Of Churned Customers")
plt.show()

# %% [markdown]
# Majority of the payments method choosen by churned cutomers was mailed check.

# %% [markdown]
# # Multivariate Analysis

# %%
df.head()
# Out:
#    CustomerID        Country       State         City   Latitude   Longitude  \
# 0  3668-QPYBK  United States  California  Los Angeles  33.964131 -118.272783
# 1  9237-HQITU  United States  California  Los Angeles  34.059281 -118.307420
# 2  9305-CDSKC  United States  California  Los Angeles  34.048013 -118.293953
# 3  7892-POOKP  United States  California  Los Angeles  34.062125 -118.315709
# 4  0280-XJGEX  United States  California  Los Angeles  34.039224 -118.266293
#
#    Gender Senior Citizen Partner Dependents  ...  Streaming Movies  \
# 0    Male             No      No         No  ...                No
# 1  Female             No      No        Yes  ...                No
# 2  Female             No      No        Yes  ...               Yes
# 3  Female             No     Yes        Yes  ...               Yes
# 4    Male             No      No        Yes  ...               Yes
#
#          Contract Paperless Billing             Payment Method  \
# ...

# %% [markdown]
# It's time to see the correlation of all data attributes.

# %%
df.corr()
# Out:
#                  Latitude  Longitude  Tenure Months  Monthly Charges  \
# Latitude         1.000000  -0.876779      -0.001631        -0.019899
# Longitude       -0.876779   1.000000      -0.001678         0.024098
# Tenure Months   -0.001631  -0.001678       1.000000         0.247900
# Monthly Charges -0.019899   0.024098       0.247900         1.000000
# Total Charges   -0.010313   0.009047       0.825880         0.651065
# Churn Score     -0.007684   0.004260      -0.224987         0.133754
# CLTV             0.000886   0.000485       0.396406         0.098693
#
#                  Total Charges  Churn Score      CLTV
# Latitude             -0.010313    -0.007684  0.000886
# Longitude             0.009047     0.004260  0.000485
# Tenure Months         0.825880    -0.224987  0.396406
# Monthly Charges       0.651065     0.133754  0.098693
# Total Charges         1.000000    -0.124312  0.341837
# Churn Score          -0.124312     1.000000 -0.079782
# ...

# %%
plt.figure(figsize=(8,8))
heat_map = sns.heatmap(df.corr(),annot = True)
plt.title( "HeatMap using Seaborn Method" )
plt.show()

# %% [markdown]
# # Observations
#
# 1 . The above heatmap martrix shows the correlation between the data attributes.The values always will be in the range of (-1 to 1) respectively. It is shown that deeper the color , more will the negative correlation and lighter the color, more will be the positive correlation.
#
# 2 . It is shown that there is a postive correlation between Tanure months and monthly charges, it means higher will be the tenuarity higher will be the monthly charges.

# %%
sns.pairplot(df)

# %% [markdown]
# # Confidence Interval
#
#
#
# The interval that you calculated is called Confidence Interval. The width of the interval is mostly decided by the business: Typically 90%, 95%, or 99%. Play around with the width parameter and
# report the observations.

# %% [markdown]
# In order to calculate the confidence interval typically in 90% ,  95% and 99%. Its required to find the mean and standard deviation.

# %%
mean = df["Total Charges"].mean()
mean
# Out:
# 2283.3004408418656

# %%
std = df["Total Charges"].std()
std
# Out:
# 2266.771361883145

# %%
n = len(df["Total Charges"])
n
# Out:
# 7043

# %% [markdown]
# The Z-multiplier for 90% , 95% or 99% are given as:

# %%
res = [[np.round(mean -(i*(std / np.sqrt(n))),2), np.round(mean +
(i*(std / np.sqrt(n))),2)] for i in [1.645, 1.96, 2.57]]
res
# Out:
# [[2238.87, 2327.73], [2230.36, 2336.24], [2213.88, 2352.72]]

# %% [markdown]
# It should be noticeable from the above that for 90% C.I the total charges will be between(2327.73 , 2238.87) , for 95% the total charges will be between(2230.36 , 2336.24) and for 99% it will be between(2213.88 , 2352.72).

# %%
df.head()
# Out:
#    CustomerID        Country       State         City   Latitude   Longitude  \
# 0  3668-QPYBK  United States  California  Los Angeles  33.964131 -118.272783
# 1  9237-HQITU  United States  California  Los Angeles  34.059281 -118.307420
# 2  9305-CDSKC  United States  California  Los Angeles  34.048013 -118.293953
# 3  7892-POOKP  United States  California  Los Angeles  34.062125 -118.315709
# 4  0280-XJGEX  United States  California  Los Angeles  34.039224 -118.266293
#
#    Gender Senior Citizen Partner Dependents  ...  Streaming Movies  \
# 0    Male             No      No         No  ...                No
# 1  Female             No      No        Yes  ...                No
# 2  Female             No      No        Yes  ...               Yes
# 3  Female             No     Yes        Yes  ...               Yes
# 4    Male             No      No        Yes  ...               Yes
#
#          Contract Paperless Billing             Payment Method  \
# ...

# %%
#CLT on total charges based on gender.

# %%
sns.displot(data = df , x = "Total Charges" , hue = "Gender" , bins = 10)
plt.show()

# %% [markdown]
# We can clearly observe that number of males are more as campared to females based on the charges.

# %%
sns.displot(data = df , x = "Total Charges" , hue = "Partner" , bins = 10)
plt.show()

# %% [markdown]
# We can observe that unmarried have paid the more charges more as compared to married.

# %%
sns.displot(data = df , x = "Total Charges" , hue = "Churn Label" , bins = 10)
plt.show()

# %% [markdown]
# We can observe that plenty of customers have not left the company which have taken the more number of subsciption and paid more charges.

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# Hypothesis testing in statistics is a way for you to test the results of a survey or experiment to see if you have meaningful results. You’re basically testing whether your results are valid by figuring out the odds that your results have happened by chance. If your results may have happened by chance, the experiment won’t be repeatable and so has little use.
#
# Hypothesis testing can be one of the most confusing aspects for students, mostly because before you can even perform a test, you have to know what your null hypothesis is. Often, those tricky word problems that you are faced with can be difficult to decipher. But it’s easier than you think; all you need to do is:
#
# Figure out your null hypothesis,
# State your null hypothesis,
# Choose what kind of test you need to perform,
# Either support or reject the null hypothesis.

# %%
df.columns
# Out:
# Index(['CustomerID', 'Country', 'State', 'City', 'Latitude', 'Longitude',
#        'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Country            7043 non-null   object
#  2   State              7043 non-null   object
#  3   City               7043 non-null   object
#  4   Latitude           7043 non-null   float64
#  5   Longitude          7043 non-null   float64
#  6   Gender             7043 non-null   object
#  7   Senior Citizen     7043 non-null   object
#  8   Partner            7043 non-null   object
#  9   Dependents         7043 non-null   object
#  10  Tenure Months      7043 non-null   int64
#  11  Phone Service      7043 non-null   object
#  12  Multiple Lines     7043 non-null   object
#  13  Internet Service   7043 non-null   object
#  14  Online Security    7043 non-null   object
#  15  Online Backup      7043 non-null   object
# ...

# %%
pd.crosstab(df["Churn Label"],columns=[df["Contract"]])
# Out:
# Contract     Month-to-month  One year  Two year
# Churn Label
# No                     2220      1307      1647
# Yes                    1655       166        48

# %% [markdown]
# Lets check that if Churn Label is dependent or independent on Contract period.

# %% [markdown]
# # Let's define Null and Alternative hypothesis
#
# # Null Hypothesis = H0 = Churn Label is independent of Contract Period
#
# # Alternate Hypothesis = Ha = Churn Label is depedent on Contract Period
#
# # Significance Value(Alpha) = 0.05

# %% [markdown]
# a . if p-value > significance value (we will failed to reject the null hypothesis)
#
# a . if p_value < significance value (we will reject the null hypothesis)

# %%
alpha = 0.05
data = pd.crosstab(df["Churn Label"] , df["Contract"])
stats , p_value , dof , expected = sts.chi2_contingency(data)
print("Statistical_value: " , stats)
print("P_value: " , p_value)
print("degrees of freedom: " , dof)
print("Expected values: " , expected)
if p_value >= alpha:
    print("P_value is greater than significance value, hence we will failed to reject the null hypothesis")
else:
    print("P_value is smaller than significance value, hence we will reject the null hypothesis")
# Out:
# Statistical_value:  1184.5965720837926
# P_value:  5.863038300673391e-258
# degrees of freedom:  2
# Expected values:  [[2846.69175067 1082.11018032 1245.198069  ]
#  [1028.30824933  390.88981968  449.801931  ]]
# P_value is smaller than significance value, hence we will reject the null hypothesis

# %% [markdown]
# # Observations
#
# 1 . We saw from the above that Churn Label is slighly dependent on Contract period and it means that there will be relationship between churning of customers and the contract period.
#
# 2 . Since, the p-value is very smaller as compared to significance value, hence we will reject the null hypothesis.
#
# 3 . The test_statitical value we get from the test is 1184.5965720837926.
#
# 4 . The p_value we got from the test is p_value = 5.863038300673391e-258 which is very smaller than significance value(alpha). Consequently, we will reject the null hypothesis because it will lie
# outside the region.

# %%
pd.crosstab(df["Churn Label"],columns=[df["Tech Support"]])
# Out:
# Tech Support    No  No internet service   Yes
# Churn Label
# No            2027                 1413  1734
# Yes           1446                  113   310

# %% [markdown]
# Lets check that if Churn Label is dependent or independent on Tech Support.

# %% [markdown]
# # Let's define Null and Alternative hypothesis
#
# # Null Hypothesis = H0 = Churn Label is independent of Tech Support
#
# # Alternate Hypothesis = Ha = Churn Label is depedent on Tech Support
#
# # Significance Value(Alpha) = 0.05

# %% [markdown]
# a . if p-value > significance value (we will failed to reject the null hypothesis)
#
# a . if p_value < significance value (we will reject the null hypothesis)

# %%
alpha = 0.05
data = pd.crosstab(df["Churn Label"] , df["Tech Support"])
stats , p_value , dof , expected = sts.chi2_contingency(data)
print("Statistical_value: " , stats)
print("P_value: " , p_value)
print("degrees of freedom: " , dof)
print("Expected values: " , expected)
if p_value >= alpha:
    print("P_value is greater than significance value, hence we will failed to reject the null hypothesis")
else:
    print("P_value is smaller than significance value, hence we will reject the null hypothesis")
# Out:
# Statistical_value:  828.1970684587393
# P_value:  1.4430840279999813e-180
# degrees of freedom:  2
# Expected values:  [[2551.37043873 1121.04557717 1501.5839841 ]
#  [ 921.62956127  404.95442283  542.4160159 ]]
# P_value is smaller than significance value, hence we will reject the null hypothesis

# %% [markdown]
# # Observations
#
# 1 . We saw from the above that Churn Label is slighly dependent on Tech Support and it means that there will be relationship between churning of customers and the Tech Support.
#
# 2 . Since, the p-value is very smaller as compared to significance value, hence we will reject the null hypothesis.
#
# 3 . The test_statitical value we get from the test is 828.1970684587393.
#
# 4 . The p_value we got from the test is p_value = 1.4430840279999813e-180 which is very smaller than significance value(alpha). Consequently, we will reject the null hypothesis because it will lie
# outside the region.

# %% [markdown]
# # Recommendations
#
#
# 1 . The most important reason directly comes from churn reason column i.e customer service has to be improved.
#
# 2 . As most of the customers left within the very 1st month, so special offers for initial months 2-3 months have to be provided so that customers gets past through most churn prone period.
#
# 3 . Urging customers to take 1 or 2 year contract instead of month to month by giving some extra benefits.
#
# 4 . Depending on the monthly bill,if it falls inside the 95% confidence interval of churned customers then provide extra offers for those customers.
#
# 5 . Churning have a strong dependency on tech support,hence improving tech support and making it accesssible to all customers by lowering extra charge will reduce churning to an extent.
#
# 6 . There are plenty of customers who left the company because of the rude behaviour of customer support service. The company should provide behavioural trainings to all the employees to reduce the chances of bad attitude,so that they can provide the full support to customers.
